# %% [markdown]
# # Task
# Analyze the 'StudentsPerformance.csv' dataset by loading it, inspecting its structure, calculating descriptive statistics, checking for missing values, and visualizing the distributions of both numerical and categorical features.

# %% [markdown]
# ## Load and inspect data
#
# ### Subtask:
# Load the 'StudentsPerformance.csv' file into a pandas DataFrame, display the first few rows, and show basic information about the dataset.

# %% [markdown]
# **Reasoning**:
# First, I'll import the pandas library to enable data manipulation. Then, I'll load the 'StudentsPerformance.csv' dataset into a DataFrame and display the initial rows to understand its structure. Finally, I'll print a concise summary to check data types and non-null values, which is essential for data cleaning and analysis.

# %%
import pandas as pd

df = pd.read_csv('StudentsPerformance.csv')

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nConcise summary of the DataFrame:")
df.info()
# Out:
# First 5 rows of the DataFrame:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
# Concise summary of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# ...

# %% [markdown]
# ### Reasoning:
# To visualize the distributions of categorical features, I will use `seaborn.countplot` for each categorical column. I will iterate through all `object` dtype columns, create a count plot for each, set appropriate titles, and ensure a tight layout before displaying the plots. This will help us understand the frequency of each category within these features.

# %% [markdown]
# ## Descriptive statistics
#
# ### Subtask:
# Calculate and display descriptive statistics for all numerical columns in the dataset.

# %% [markdown]
# **Reasoning**:
# To calculate and display descriptive statistics for all numerical columns as requested by the subtask, I will use the `.describe()` method on the DataFrame.

# %%
print("\nDescriptive statistics for numerical columns:")
print(df.describe())
# Out:
# Descriptive statistics for numerical columns:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Check for missing values
#
# ### Subtask:
# Identify and report any missing values present in the dataset.

# %% [markdown]
# **Reasoning**:
# To identify and report missing values, I will use the `.isnull()` method to create a boolean DataFrame indicating missing values, and then chain `.sum()` to count the number of `True` values (missing values) for each column.

# %%
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ## Visualize numerical distributions
#
# ### Subtask:
# Generate visualizations (e.g., histograms, box plots) to show the distribution of numerical features.

# %% [markdown]
# **Reasoning**:
# To visualize the distributions of numerical features, I will import `matplotlib.pyplot` and `seaborn`, then generate histograms with KDE and box plots for 'math score', 'reading score', and 'writing score', ensuring proper titles and layout, and finally display all plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = ['math score', 'reading score', 'writing score']

# Histograms
plt.figure(figsize=(15, 5))
for i, col in enumerate(numerical_cols):
    plt.subplot(1, 3, i + 1)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col.replace("_", " ").title()}')
plt.tight_layout()
plt.show()

# Box plots
plt.figure(figsize=(15, 5))
for i, col in enumerate(numerical_cols):
    plt.subplot(1, 3, i + 1)
    sns.boxplot(y=df[col])
    plt.title(f'Box Plot of {col.replace("_", " ").title()}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize categorical distributions
#
# ### Subtask:
# Generate visualizations (e.g., count plots, bar charts) to show the distribution of categorical features.
#
# Which subject (math, reading, writing) shows the biggest performance gap between demographic groups?

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `StudentsPerformance.csv` dataset was successfully loaded, comprising 1000 entries and 8 columns, with no missing values identified across any column.
# *   The dataset includes five categorical columns (`gender`, `race/ethnicity`, `parental level of education`, `lunch`, `test preparation course`) and three numerical columns (`math score`, `reading score`, `writing score`).
# *   Descriptive statistics for numerical scores show:
#     *   `math score`: Mean of $\approx$ 66.09, standard deviation of $\approx$ 15.16, with scores ranging from 0 to 100.
#     *   `reading score`: Mean of $\approx$ 69.17, standard deviation of $\approx$ 14.60, with scores ranging from 17 to 100.
#     *   `writing score`: Mean of $\approx$ 68.05, standard deviation of $\approx$ 15.20, with scores ranging from 10 to 100.
# *   While all subjects have similar average scores and spread, the minimum score in `math score` is 0, which is considerably lower than the minimums for `reading score` (17) and `writing score` (10), indicating potential outliers or a segment of students performing extremely poorly in mathematics.
# *   Histograms and box plots were generated for all numerical features, providing visual representations of their distributions and aiding in the identification of central tendency, spread, and potential outliers.
#
# ### Insights or Next Steps
#
# *   Investigate the factors contributing to the extremely low `math score` (0) observed in the dataset, potentially by correlating with categorical features.
# *   Proceed with visualizing the distributions of categorical features to understand their composition and prepare for further inferential analysis.

# %%
categorical_cols = df.select_dtypes(include='object').columns

plt.figure(figsize=(20, 15))
for i, col in enumerate(categorical_cols):
    plt.subplot(3, 2, i + 1) # Adjust subplot grid as needed
    sns.countplot(x=df[col], palette='viridis', hue=df[col], legend=False)
    plt.title(f'Distribution of {col.replace("_", " ").title()}')
    plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# What is the average math, reading, and writing score across all students?

# %%
import numpy as np
print(df.describe())
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# How do test scores differ between male and female students?

# %%
gender_scores = df.groupby('gender')[['math score', 'reading score', 'writing score']].mean()
gender_scores
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %% [markdown]
# Which racial/ethnic group has the highest average overall performance?

# %%
race_ethnicity = df.groupby('race/ethnicity')[['math score', 'reading score', 'writing score']].mean()
race_ethnicity
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %% [markdown]
# as we can see the group e have more score followed by d,c,b,a

# %% [markdown]
# What is the distribution of parental education levels in the dataset?

# %%
numerical_cols = ['math score', 'reading score', 'writing score']

# A subplot means multiple plots inside one single figure. plt.subplot(1, 3, 1)   # Row 1, Column 3, Plot 1
plt.figure(figsize=(15, 5))
for i, col in enumerate(numerical_cols):
    plt.subplot(1, 3, i + 1)
    sns.histplot(df['parental level of education'], kde=True)
    plt.xticks(rotation=45)
    plt.title('parental level of education')
plt.tight_layout()
plt.show()

# %% [markdown]
# relationship of parental level of education and kids score

# %%
parental_education_vs_kids_score = df.groupby('parental level of education')[['math score', 'reading score', 'writing score']].mean()
parental_education_vs_kids_score
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
plt.figure(figsize=(10,5))
scores = ["math score", "reading score", "writing score"]

for score in scores:
    sns.barplot(data=df, x="parental level of education", y=score)
    plt.title(f"{score} vs Parental Level of Education")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# as we can see there is a minor pattern in parental education and students performance a parents who completed master's degree have student with higher markes followed by bachelor's , associate's , some collage , some high school , high school . it conclusion that parenting is important !.
# How do scores compare between students whose parents have higher vs lower education levels?

# %% [markdown]
# Does completing the test preparation course significantly improve test scores?

# %%
effect_of_test_preparation_course_on_score = df.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean()
effect_of_test_preparation_course_on_score
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
# Is there a correlation between lunch type (standard vs free/reduced) and academic performance?

# %%
relation_between_lunch_performance= df.groupby('lunch')[['math score', 'reading score', 'writing score']].mean()
relation_between_lunch_performance
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %% [markdown]
# the students who have standard lunch are having more score than free/reduced .

# %% [markdown]
# What recommendations can be made to improve the performance of low-scoring groups?

# %% [markdown]
# suggesting add standard lunch and test prepration course

# %% [markdown]
# Which factors should schools prioritize to close achievement gaps?

# %% [markdown]
# make test preparation course compulsory and provide standard lunch

# %% [markdown]
# What insights from the data could inform educational resource allocation?

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Task
# Generate a comprehensive summary of insights from the 'StudentsPerformance.csv' dataset to inform educational resource allocation, focusing on the impact of parental education, test preparation courses, lunch type, gender, and racial/ethnic group on student performance.

# %% [markdown]
# ## Analyze Parental Education Impact
#
# ### Subtask:
# Examine how different parental education levels correlate with student scores across subjects to identify groups that may require additional support.

# %% [markdown]
# ### Reasoning:
# I have already generated the `parental_education_vs_kids_score` DataFrame which contains the average scores for each parental education level, and the bar plots visualizing this relationship. Now, I will analyze these outputs to describe the correlation between parental education and student performance across subjects, and identify the groups with higher and lower scores, fulfilling the remaining instructions of the subtask.

# %% [markdown]
# ### Analysis of Parental Education Impact on Student Scores:
#
# Based on the `parental_education_vs_kids_score` DataFrame and the generated bar plots, a discernible pattern emerges regarding the correlation between parental education levels and student performance across math, reading, and writing scores.
#
# *   **Higher-Performing Groups:**
#     *   Students whose parents have a **Master's Degree** consistently show the highest average scores across all three subjects (math: ~69.75, reading: ~75.37, writing: ~75.68).
#     *   Following closely are students with parents who hold a **Bachelor's Degree** (math: ~69.39, reading: ~73.00, writing: ~73.38).
#     *   Parents with an **Associate's Degree** also show above-average scores, particularly in reading and writing.
#
# *   **Lower-Performing Groups:**
#     *   Students whose parents' highest education level is **High School** consistently exhibit the lowest average scores across all subjects (math: ~62.14, reading: ~64.70, writing: ~62.45).
#     *   Similarly, students whose parents have "**some high school**" education also fall into the lower-performing category (math: ~63.50, reading: ~66.94, writing: ~64.89).
#
# *   **Intermediate Groups:**
#     *   Students whose parents have "**some college**" education show scores that are generally in the mid-range, higher than high school education but lower than bachelor's or master's degrees.
#
# **Overall Correlation:** There appears to be a positive correlation between the level of parental education and student test scores. Generally, as the parental education level increases, so do the average scores of their children in math, reading, and writing. This suggests that parental education level could be an influential factor in a student's academic performance.
#
# **Groups Requiring Additional Support:** Students whose parents have **High School** or **some high school** as their highest education level are the groups that appear to require the most additional support, as their average scores are significantly lower across all subjects compared to students with more highly educated parents.

# %% [markdown]
# ## Evaluate Test Preparation Course Effectiveness
#
# ### Subtask:
# Assess the impact of completing test preparation courses on student performance to determine if mandating or promoting these courses could be an effective resource allocation strategy.

# %% [markdown]
# From the `effect_of_test_preparation_course_on_score` DataFrame, we can observe the following average scores based on test preparation course completion:
#
# *   **Math Score:**
#     *   Completed: 69.69
#     *   None: 64.08
#     *   Difference: +5.61 points for completed.
#
# *   **Reading Score:**
#     *   Completed: 73.89
#     *   None: 66.53
#     *   Difference: +7.36 points for completed.
#
# *   **Writing Score:**
#     *   Completed: 74.42
#     *   None: 64.50
#     *   Difference: +9.92 points for completed.
#
# **Conclusion:**
# Students who completed the test preparation course consistently showed higher average scores across all three subjects (math, reading, and writing) compared to those who did not. The improvement is most pronounced in writing score (+9.92 points) and reading score (+7.36 points), with a notable increase in math score as well (+5.61 points).
#
# Based on this analysis, promoting or mandating test preparation courses could be an effective strategy for improving overall student performance, as a clear positive impact is observed across all subjects.

# %% [markdown]
# ## Investigate Lunch Type Influence
#
# ### Subtask:
# Determine the correlation between lunch type (standard vs. free/reduced) and student scores to understand if nutritional support plays a significant role in academic performance and resource allocation.

# %% [markdown]
# ### Analysis of Lunch Type and Academic Performance
#
# The `relation_between_lunch_performance` DataFrame provides insights into how different lunch types correlate with academic scores:
#
# *   **Math Score**: Students with 'standard' lunch have an average math score of approximately 70.03, while those with 'free/reduced' lunch have an average of approximately 58.92. This represents a significant difference of over 11 points.
# *   **Reading Score**: Similarly, students with 'standard' lunch scored an average of approximately 71.65 in reading, compared to approximately 64.65 for 'free/reduced' lunch students, a difference of about 7 points.
# *   **Writing Score**: For writing, 'standard' lunch students achieved an average of approximately 70.82, whereas 'free/reduced' lunch students averaged about 63.02, indicating a difference of approximately 7.8 points.
#
# **Summary:**
# There is a clear and consistent pattern across all three subjects: students who receive 'standard' lunch consistently outperform students who receive 'free/reduced' lunch. The performance gap is most pronounced in math scores. This suggests a strong positive correlation between having a standard lunch (which might imply better nutritional access or socio-economic status) and higher academic performance.
#
# **Implications for Nutritional Support and Resource Allocation:**
# This finding strongly suggests that nutritional support, as indicated by lunch type, plays a significant role in academic performance. Students with 'free/reduced' lunch, who are typically from lower socio-economic backgrounds, show lower scores across the board. This data could inform resource allocation decisions by highlighting the need for enhanced nutritional programs or other support mechanisms for students receiving 'free/reduced' lunch to help bridge this achievement gap.

# %% [markdown]
# ## Assess Gender-Based Score Differences
#
# ### Subtask:
# Analyze the average scores across subjects for male and female students to identify any significant performance gaps that could inform gender-specific interventions or resource allocation.

# %% [markdown]
# **Reasoning**:
# I will display the `gender_scores` DataFrame again to easily refer to the average scores for male and female students across different subjects, which is essential for quantifying the differences and identifying performance gaps.

# %%
print("Average scores by gender:")
print(gender_scores)
# Out:
# Average scores by gender:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %% [markdown]
# ### Analysis of Gender-Based Score Differences:
#
# From the `gender_scores` DataFrame, we can observe the following average scores and differences between male and female students:
#
# *   **Math Score:**
#     *   Female: 63.63
#     *   Male: 68.73
#     *   **Difference:** Males score approximately 5.10 points higher than females in math.
#
# *   **Reading Score:**
#     *   Female: 72.61
#     *   Male: 65.47
#     *   **Difference:** Females score approximately 7.14 points higher than males in reading.
#
# *   **Writing Score:**
#     *   Female: 72.47
#     *   Male: 63.31
#     *   **Difference:** Females score approximately 9.16 points higher than males in writing.
#
# **Summary of Findings:**
# There are significant and distinct performance gaps between genders across the subjects:
# *   **Males show a notable advantage in Math scores.**
# *   **Females show a substantial advantage in Reading and Writing scores.** The difference is particularly pronounced in writing.
#
# **Implications for Gender-Specific Interventions or Resource Allocation:**
# These findings suggest that a one-size-fits-all approach to educational support might not be optimal.
# *   **For Math:** Interventions or additional resources could be directed towards female students to boost their performance in mathematics. This might include targeted tutoring, mentorship programs, or pedagogical approaches that address potential confidence gaps or learning styles.
# *   **For Reading and Writing:** Conversely, male students could benefit from interventions focused on improving reading comprehension and writing skills. This could involve specialized literacy programs, encouraging reading habits, or creative writing workshops tailored for male students.
#
# Understanding these gender-based disparities allows for more informed and targeted resource allocation to help close achievement gaps and ensure equitable educational outcomes for all students.

# %% [markdown]
# ## Examine Racial/Ethnic Group Performance
#
# ### Subtask:
# Review the average scores for different racial/ethnic groups to identify disparities that may require targeted resource allocation or support programs.

# %% [markdown]
# **Reasoning**:
# To begin the analysis of racial/ethnic group performance, I will first display the 'race_ethnicity' DataFrame, which contains the average scores for each group across all subjects. This step directly addresses the first instruction of the subtask.

# %%
print("Average scores by race/ethnicity group:")
print(race_ethnicity)
# Out:
# Average scores by race/ethnicity group:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %% [markdown]
# ### Analysis of Racial/Ethnic Group Performance:
#
# From the `race_ethnicity` DataFrame, the following patterns emerge regarding student performance across different racial/ethnic groups:
#
# *   **Performance Gradient:** There's a clear gradient in average scores across the groups, with Group E consistently performing the highest and Group A consistently performing the lowest across all three subjects.
#
# *   **Highest Performing Group (Group E):**
#     *   Math Score: ~73.82
#     *   Reading Score: ~73.03
#     *   Writing Score: ~71.41
#     This group demonstrates the strongest overall academic performance.
#
# *   **Lowest Performing Group (Group A):**
#     *   Math Score: ~61.63
#     *   Reading Score: ~64.67
#     *   Writing Score: ~62.67
#     This group shows the lowest average scores in all subjects, with a particularly noticeable gap in math compared to Group E (over 12 points).
#
# *   **Intermediate Groups:**
#     *   Group B, C, and D fall in between, with a gradual increase in scores from Group B to Group D. Group D generally performs well, nearing Group E's scores in some instances.
#
# **Summary of Performance Disparities:**
# There are significant and consistent achievement gaps among the racial/ethnic groups. Group E consistently outperforms all other groups, while Group A consistently underperforms. The difference between the highest and lowest performing groups is substantial, particularly in math scores.
#
# **Implications for Targeted Resource Allocation or Support Programs:**
# These disparities highlight the need for targeted interventions and resource allocation to address the achievement gaps. Schools and educational authorities should:
# *   **Focus on Group A and B:** These groups show the lowest average scores and would likely benefit most from enhanced support programs. This could include supplementary instruction, tutoring, mentorship programs, or addressing underlying socio-economic factors that might contribute to lower performance.
# *   **Investigate Contributing Factors:** Further research could be conducted to understand the specific factors contributing to these performance differences (e.g., access to resources, quality of schooling, socio-economic status, cultural factors). This would allow for more precise and effective resource allocation.
# *   **Equity-Focused Policies:** Implement policies aimed at promoting educational equity, ensuring that all students, regardless of their racial/ethnic background, have access to high-quality educational resources and opportunities. The goal should be to uplift the performance of lower-scoring groups closer to the levels of higher-scoring groups.

# %% [markdown]
# ## Synthesize Insights and Recommend Resource Allocation
#
# ### Subtask:
# Combine the findings from all analyses to provide actionable insights and concrete recommendations for how educational resources can be allocated to address identified achievement gaps and improve overall student performance.

# %% [markdown]
# ### Combined Insights and Recommendations for Resource Allocation:
#
# This comprehensive analysis of the `StudentsPerformance.csv` dataset reveals several critical factors influencing student performance, highlighting key achievement gaps and areas for targeted intervention. Below is a synthesis of these insights and actionable recommendations for educational resource allocation.
#
# #### Key Findings Summary:
#
# 1.  **Parental Education Impact:**
#     *   **Insight:** There's a strong positive correlation between parental education level and student scores. Students with parents holding Master's or Bachelor's degrees consistently outperform those whose parents have High School or 'some high school' education.
#     *   **Achievement Gap:** Students with parents having High School or some high school education are the lowest-performing group.
#
# 2.  **Test Preparation Course Effectiveness:**
#     *   **Insight:** Completing a test preparation course significantly boosts scores across all subjects, with the most substantial improvements seen in writing (+9.92 points) and reading (+7.36 points).
#     *   **Performance Advantage:** Students who completed the course consistently achieved higher scores.
#
# 3.  **Lunch Type Influence:**
#     *   **Insight:** Students receiving 'standard' lunch consistently outperform those on 'free/reduced' lunch across all subjects, with the largest gap in math scores (>11 points).
#     *   **Achievement Gap:** Students receiving 'free/reduced' lunch are a significantly lower-performing group, indicating a potential link between socio-economic status, nutrition, and academic success.
#
# 4.  **Gender-Based Score Differences:**
#     *   **Insight:** Males outperform females in math by approximately 5 points, while females significantly outperform males in reading (7.14 points) and writing (9.16 points).
#     *   **Achievement Gaps:** Females in math; Males in reading and writing.
#
# 5.  **Racial/Ethnic Group Performance:**
#     *   **Insight:** Group E consistently shows the highest average scores across all subjects, followed by Group D. Group A generally exhibits the lowest performance.
#     *   **Achievement Gap:** Group A and B are generally the lowest-performing groups, while Group E and D are the highest.
#
# #### Actionable Recommendations for Resource Allocation:
#
# Based on these insights, educational resources should be strategically allocated to address identified disparities and uplift overall student performance:
#
# 1.  **Targeted Support for Parental Education Gaps:**
#     *   **Recommendation:** Implement programs (e.g., workshops, parent-teacher collaboration initiatives, literacy resources) specifically designed for parents with lower educational attainment (High School, some high school) to equip them with tools to support their children's learning at home. This can include digital literacy, homework support, and access to educational resources.
#     *   **Resource Allocation:** Funding for parent engagement coordinators, educational materials, and community-based learning centers.
#
# 2.  **Mandate or Strongly Promote Test Preparation Courses:**
#     *   **Recommendation:** Given the clear positive impact, schools should consider making test preparation courses compulsory or integrating core elements of these courses into the regular curriculum, especially focusing on writing and reading skills development.
#     *   **Resource Allocation:** Investment in qualified instructors, curriculum development for test preparation, and free access to online test prep platforms.
#
# 3.  **Enhance Nutritional Support and Socio-economic Interventions:**
#     *   **Recommendation:** Prioritize resources for students receiving 'free/reduced' lunch. This includes ensuring access to nutritious meals (e.g., breakfast programs, healthy snack options) and exploring broader socio-economic support initiatives that address underlying factors impacting performance (e.g., after-school programs, access to learning materials).
#     *   **Resource Allocation:** Increased funding for school meal programs, extended school day programs for tutoring and enrichment, and partnerships with community organizations.
#
# 4.  **Gender-Specific Academic Support Programs:**
#     *   **Recommendation:** Develop and implement targeted interventions:
#         *   **For Females in Math:** Create engaging STEM programs, mentorship opportunities with female role models in STEM, and specific tutoring tailored to math concepts for female students.
#         *   **For Males in Reading and Writing:** Introduce diverse reading materials, creative writing workshops, and literacy support programs that resonate with male students' interests.
#     *   **Resource Allocation:** Funding for specialized educators, curriculum enhancements, and extracurricular activities promoting gender balance in different subjects.
#
# 5.  **Address Racial/Ethnic Disparities through Culturally Responsive Teaching:**
#     *   **Recommendation:** Conduct further qualitative research to understand the specific barriers and needs of lower-performing racial/ethnic groups (e.g., Group A, Group B). Implement culturally responsive teaching practices, provide resources for diverse learning styles, and ensure equitable access to high-quality instruction and support services.
#     *   **Resource Allocation:** Professional development for teachers in culturally responsive pedagogy, funding for diverse educational materials, and dedicated support staff for at-risk groups.
#
# By systematically addressing these identified areas, educational institutions can allocate resources more effectively to reduce achievement gaps and foster an environment where all students have the opportunity to succeed.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide a comprehensive summary of insights for educational resource allocation based on the data analysis.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Parental Education's Impact**: A strong positive correlation exists between parental education level and student performance. Students whose parents hold Master's or Bachelor's degrees consistently achieve the highest average scores across all subjects, while those whose parents have only a High School education or "some high school" exhibit the lowest average scores.
# *   **Test Preparation Course Effectiveness**: Completing a test preparation course significantly improves student scores across all subjects. The most substantial improvements were observed in writing (an increase of 9.92 points), followed by reading (an increase of 7.36 points), and math (an increase of 5.61 points).
# *   **Lunch Type Influence**: Students receiving 'standard' lunch consistently outperform those on 'free/reduced' lunch across all subjects. The largest performance gap was seen in math scores, with 'standard' lunch students scoring over 11 points higher on average.
# *   **Gender-Based Score Differences**: There are distinct performance gaps between genders. Males scored approximately 5.10 points higher than females in math, while females significantly outperformed males in reading (by about 7.14 points) and writing (by about 9.16 points).
# *   **Racial/Ethnic Group Performance**: Significant and consistent achievement gaps were identified among racial/ethnic groups. Group E consistently showed the highest average scores across all subjects, while Group A consistently exhibited the lowest performance, with a difference of over 12 points in math scores between the two groups.
#
# ### Insights or Next Steps
#
# *   **Targeted Resource Allocation**: Educational resources should be strategically allocated to address the identified achievement gaps, focusing on groups with lower performance based on parental education (High School/some high school), lunch type (free/reduced), and specific racial/ethnic groups (Group A and B).
# *   **Promote Test Preparation & Socio-economic Support**: Given the clear benefits, consider making test preparation courses more accessible or compulsory. Additionally, enhance nutritional programs and provide broader socio-economic support for students from disadvantaged backgrounds, as indicated by 'free/reduced' lunch status and lower parental education levels.
